# %% [markdown]
# Setup: Install and import libraries

# %%
# !pip install --upgrade gensim scikit-learn plotly
# Out:
# Collecting gensim
#   Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (5.24.1)
# Collecting plotly
#   Downloading plotly-6.3.1-py3-none-any.whl.metadata (8.5 kB)
# Collecting numpy<2.0,>=1.18.5 (from gensim)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 3.2 MB/s eta 0:00:00
# Collecting scipy<1.14.0,>=1.7.0 (from gensim)
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.3.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly) (2.7.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from plotly) (25.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart-open>=1.8.1->gensim) (1.17.3)
# Downloading gensim-4.3.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 72.5 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 112.3 MB/s eta 0:00:00
# Downloading plotly-6.3.1-py3-none-any.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 112.8 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 94.0 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 12.6 MB/s eta 0:00:00
# Installing collected packages: plotly, numpy, scipy, scikit-learn, gensim
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.2
#     Uninstalling scipy-1.16.2:
#       Successfully uninstalled scipy-1.16.2
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.6.1
#     Uninstalling scikit-learn-1.6.1:
#       Successfully uninstalled scikit-learn-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# tsfresh 0.21.1 requires scipy>=1.14.0; python_version >= "3.10", but you have scipy 1.13.1 which is incompatible.
# Successfully installed gensim-4.3.3 numpy-1.26.4 plotly-6.3.1 scikit-learn-1.7.2 scipy-1.13.1

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import gensim.downloader as api
import plotly.express as px
import os
import time

# %% [markdown]
# ## 1.Load pretrained embeddings

# %%
print("pretrained embeddings:glove-wiki-gigaword-50")
model = api.load("glove-wiki-gigaword-50")  # pretrained 50d embeddings
print(f"Loaded model. Vocab size: {len(model.index_to_key)}")
# Out:
# pretrained embeddings:glove-wiki-gigaword-50
# [==================================================] 100.0% 66.0/66.0MB downloaded
# Loaded model. Vocab size: 400000

# %% [markdown]
# ### Lấy vector của một từ

# %%
word_vector = model['python']
print(f"Vector của từ 'python':\n{word_vector}")
print(f"Kích thước vector: {len(word_vector)}")
# Out:
# Vector của từ 'python':
# [ 0.5897   -0.55043  -1.0106    0.41226   0.57348   0.23464  -0.35773
#  -1.78      0.10745   0.74913   0.45013   1.0351    0.48348   0.47954
#   0.51908  -0.15053   0.32474   1.0789   -0.90894   0.42943  -0.56388
#   0.69961   0.13501   0.16557  -0.063592  0.35435   0.42819   0.1536
#  -0.47018  -1.0935    1.361    -0.80821  -0.674     1.2606    0.29554
#   1.0835    0.2444   -1.1877   -0.60203  -0.068315  0.66256   0.45336
#  -1.0178    0.68267  -0.20788  -0.73393   1.2597    0.15425  -0.93256
#  -0.15025 ]
# Kích thước vector: 50

# %% [markdown]
# ### Tính độ tương đồng (similarity) giữa hai từ

# %%
# Tính độ tương đồng giữa hai từ 'king' và 'queen'
similarity_score = model.similarity('king', 'queen')
print(f"Độ tương đồng giữa 'king' và 'queen': {similarity_score:.4f}")

# Bạn có thể thử với các cặp từ khác
similarity_score_2 = model.similarity('dog', 'cat')
print(f"Độ tương đồng giữa 'dog' và 'cat': {similarity_score_2:.4f}")

similarity_score_3 = model.similarity('car', 'tree')
print(f"Độ tương đồng giữa 'car' và 'tree': {similarity_score_3:.4f}")

# %% [markdown]
# ### Tìm các từ đồng nghĩa (most similar)

# %%
# Tìm 10 từ tương tự nhất với từ 'happy'
most_similar_words = model.most_similar('happy', topn=10)
print(f"10 từ tương tự nhất với 'happy':")
for word, score in most_similar_words:
    print(f"{word}: {score:.4f}")

# Bạn có thể thử với các từ khác, ví dụ 'vietnam'
most_similar_words_vietnam = model.most_similar('vietnam', topn=10)
print(f"\n10 từ tương tự nhất với 'vietnam':")
for word, score in most_similar_words_vietnam:
    print(f"{word}: {score:.4f}")

# %% [markdown]
# ##2.Prepare a subset vocabulary and corresponding vectors

# %%
# data too big, do this 4 more easier time

# Sample sizes
num_common = 200   # top frequent-ish words (index_to_key)
num_random = 300   # additional random words
total_samples = num_common + num_random

# Sample word list
common_words = model.index_to_key[:num_common]
random_words = random.sample(model.index_to_key[num_common:], num_random)
words = common_words + random_words
len(words), words[:10]

# Vectors matrix
X = np.array([model[w] for w in words])
print("Vector matrix shape:", X.shape)
# Out:
# Vector matrix shape: (500, 100)

# %% [markdown]
# ##3.Dimensionality Reduction: PCA (2D and 3D)

# %%
pca_2d = PCA(n_components=2, random_state=42)
X_pca2 = pca_2d.fit_transform(X)
print("PCA 2D shape:", X_pca2.shape)

pca_3d = PCA(n_components=3, random_state=42)
X_pca3 = pca_3d.fit_transform(X)
print("PCA 3D shape:", X_pca3.shape)
# Out:
# PCA 2D shape: (500, 2)
# PCA 3D shape: (500, 3)

# %% [markdown]
# ##4.Dimensionality Reduction: t-SNE (2D) and (3D)
#
# - t-SNE is non-linear and often captures local neighborhood structure better.
# - It is slower; for 500 points it should be fine. We demonstrate both 2D and 3D.

# %%
tsne_2d = TSNE(n_components=2, perplexity=30, n_iter_without_progress=1000, random_state=42, init='pca')
start = time.time()
X_tsne2 = tsne_2d.fit_transform(X)
print(f"t-SNE 2D done in {time.time() - start:.2f} s")

tsne_3d = TSNE(n_components=3, perplexity=30, n_iter_without_progress=1000, random_state=42, init='pca')
start = time.time()
X_tsne3 = tsne_3d.fit_transform(X)
print(f"t-SNE 3D done in {time.time() - start:.2f} s")
# Out:
# t-SNE 2D done in 4.71 s
# t-SNE 3D done in 11.84 s

# %% [markdown]
# ##5.Visualization:

# %% [markdown]
# a) 2D (PCA & t-SNE)

# %%
# common words are shown, random ones aren't
plt.figure(figsize=(8, 4))
plt.scatter(X_pca2[:,0], X_pca2[:,1], alpha=0.7, s=20, label='words')
plt.title('PCA 2D projection of word embeddings')
for i,w in enumerate(words[:50]):  # label first 50 words for readability
    plt.text(X_pca2[i,0]+0.02, X_pca2[i,1]+0.02, w, fontsize=9)
plt.xlabel('PC1'); plt.ylabel('PC2')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 4))
plt.scatter(X_tsne2[:,0], X_tsne2[:,1], alpha=0.8, s=20)
plt.title('t-SNE 2D projection of word embeddings')
for i,w in enumerate(words[:50]):
    plt.text(X_tsne2[i,0]+0.5, X_tsne2[i,1]+0.5, w, fontsize=9)
plt.xlabel('Dim1'); plt.ylabel('Dim2')
plt.grid(True)
plt.show()

# %% [markdown]
# b) 3D (PCA & t-SNE)

# %%
df_pca3 = pd.DataFrame(X_pca3, columns=['x','y','z'])
df_pca3['word'] = words
df_pca3['type'] = ['common' if i < num_common else 'random' for i in range(len(words))]

fig_pca3 = px.scatter_3d(df_pca3, x='x', y='y', z='z', color='type', title='PCA 3D of word embeddings')
fig_pca3.update_traces(marker=dict(size=3))
fig_pca3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="0fa77d35-ea33-4877-a15e-bf6505e5dd83" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("0fa77d35-ea33-4877-a15e-bf6505e5dd83")) {                    Plotly.newPlot(                        "0fa77d35-ea33-4877-a15e-bf6505e5dd83",                        [{"hovertemplate":"type=common\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"common","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"common","scene":"scene","showlegend":true,"x":{"dtype":"f4","bdata":"0I6AwKb0acBrt3TAzG14wC9DiMA3B3fAkIV9wI7GecCyGV7AqcSCwLl3gcCNs4rA8EuMwOOogsAf8G7AY8tywBI3dcBsRHvATK+FwEzNc8AnWorACeBvwOPHcMBAfjPAi2k+wHTWb8AI0H7AviBuwH4ifcAgGobAtACKwL5Of8Di2nfAmneKwKW\u002fg8Dw6nvAWv6FwG+2g8A2SHXAWl6KwDZpe8DlLIHAKQJ2wJsjg8DrvoXABPZSwMrCYcBw3H\u002fAhyF5wE29bcAQXnDASG5+wPzWYcADCYbABNKDwMfBesCJpIXAIOtSwFLXaMDMBX3AjkJ1wOGQc8DdpHfA2L11wD3wfMB1zGPAI258wGx7bcCF53LArwB0wMATfcAp3GnAsUdIwC97ecDf7nPANxZpwHJ2dsB\u002f7XfAa7BmwL8Lb8Dxi0XAs7RxwHyra8Bi43jAUMtuwMmuYcCmTWrABHRtwFwGbcBvb0LA3K9SwDVGbcCnW1rAyvtIwORCfMAJrWLAcw5wwI+kVcAXeVnAe8phwC4qc8BU63LAPXtxwEEWaMC0AFzA+chWwNnHZMA3dFnAxONdwDF0a8DK7FbAtOpXwNmaV8DWTWvAbPpcwBhvT8CzM1vA1E1ZwJ4BScC+lF\u002fAM8FowG62Q8Aw6GDANgpgwPTVUMDaTFPArNpNwLdDVsBshj\u002fAwsVAwFnFa8BOzlDATxpBwLh2XsA7dGTAgT9XwMoQSsCyAl7Aj5dXwGQnPcBYcU7A29gewOySOMBO4VjAkwxHwM70QcCkMkrAXy9cwI\u002fhTcBQ72HAJapNwA+lZMAlJUvAixNKwEXjN8Bg3mjA8qhTwOX3NcCjyV3Au2JgwNP9LMCH\u002flPAEtRlwKx7TMA3yDbAw6I1wHBcQsBxJUbA3UBEwBYkXMDOe1XAPABRwGfKPsCWyFLAOaxYwHGLN8BN3zrAuaxQwBF5QcDoOljAzhhBwIQlYMDtCVPAJydPwNQqT8AErkvACL8+wLbyVMC0L0DAy7JfwHWYWMDQFlTAT29awHNTOMB8EETASI4wwNFaOMDi+F\u002fAdUNMwNPXScA="},"y":{"dtype":"f4","bdata":"weAXv+nhtL5t\u002f1s+Lu4tv\u002fY0lrwXw0c+opuDv8JJ1L6zA4M\u002fBhkOv5bnBb9T1QC\u002f+Y1mP1iEgb\u002f5TPc+qujSvv\u002fInDwhbli+VjxEP7n5Cz77J2U\u002fzexnvzVZp78iDIW\u002fMNiCv\u002fIHjb+PjLk+eSHePwgh6T\u002fvIxq\u002fslWPP\u002ffOmr3qu6M\u002fuAGOPw5QaT9sn8A98dm6P725Cz+PFyI\u002fYwTLP\u002ftRFD4XqDxA3YK2vnhKvT5\u002fRUQ\u002f4uy3PX4sEz9SKYW\u002fPUaoPnnOtb\u002fUiGm\u002fahKOPuKZD76acxhAom8eP0chF7\u002frZho\u002fU395PzDpX79C\u002fLo9W+XbvayD4j4Ijqa\u002fpZWUPzyifT+k0x49VQgpPxMcqj\u002fazLM+F2YpPxjyHEBC3Iw\u002fxHwJwCcafD7oL4a\u002f5eknvV+Awb8BRzY\u002fb+PRv3yjcD54UuC\u002fRZNOQIZSr76K7Ms\u002fMSOZP\u002f6P876+cQ1AqzFLv39ZK0D2OCG+vsuxv+wI6z7q99K\u002fGT4dwJ32jz+leIy\u002fg+whP1nG9j428ZS\u002fBgQOwGkS7T+T8bI\u002fuD7uP1hHlz\u002fzgc2\u002f9D97v8F6Gr9q\u002fKU+LTeQvxvOgj9hG+a+e5d1PuFppL8BjZI\u002fTgz2PngVwr9oq00+2Kr3P3Ovfr9\u002fZaQ\u002fBPyBP6oQ7b\u002fQaRK\u002fZPJCv+WnKr+ouoo\u002fgPWRv8Lr3T4NroK\u002fnrGMvyfHhz+383q+Q9zZvyWQWr\u002fjxfk+nKWfviHcH79PesM+W5FhvUnSEsDJaUW\u002f+oUDwKWElL+TJ0s\u002fiTlfv73yn74Nuda\u002fJ9K6vypjtr+KW20\u002fEMZWPgE5rj86iBW\u002fY1fNvtWqqL61EpE\u002fwdDzvqCLwr\u002fot9s\u002fD\u002fmlPzGNR8CSPWU\u002fC4bQP708sr5l4s2+yLNpv0JY5b5\u002f5nU+PWwcv3I67j\u002fr84q+MFUmwG2Zp7\u002f0\u002f9Q+Ed6Dv0Cx\u002fLyWINq\u002fWVwswCdYtb9espc\u002fMQRDP1HCjD8srTW\u002fU+EiwJzZIMCGRx7An9TZPiSkAz4axBhAcKWfP5E5Hj+TqfA\u002fVQQrQKbx8b+2AZO\u002fUJKyvMnzoL\u002frwvs\u002f2KcJv+bFQL8="},"z":{"dtype":"f4","bdata":"T3\u002fvvTvEQb+obFa9nRHHPt+pwz4m8969cjIaPrQbeb35Hli\u002f5d+jv2GIDz+enYA+m5BUvwPkBb71gDe+SnmPvw3gMcC35rk+hBbNv7cYYb4b\u002f5s94A1BvYD7sD6sYe0\u002fpICuPyFzdz\u002fZ4KO\u002fa0Vnv59PO7+ook2+JBEUvtaTNr9ijIE\u002f+6LxvN9\u002fG79JZ8k+408Mv36m1j2x3Lm\u002fHXf8vdbXXL\u002fT0B+\u002f+gnVPptrzL3XaA4\u002ft1HXPta\u002f5j\u002fvGHI\u002fVxP8Pen8Jb\u002fcy+s99HkCv7tkYL9o2wi\u002foVjOvvXYID+2cqA\u002f\u002fzkmvWDBMr24WEs\u002fCpeGP+RRI79AYXY\u002fuRVUPl5LUj9DGIg+RQXTPZBZsb+mOQY\u002fOAsmP35Bor7pDmi ...

# %%
df_tsne3 = pd.DataFrame(X_tsne3, columns=['x','y','z'])
df_tsne3['word'] = words
df_tsne3['type'] = ['common' if i < num_common else 'random' for i in range(len(words))]

fig_tsne3 = px.scatter_3d(df_tsne3, x='x', y='y', z='z', color='type', title='t-SNE 3D of word embeddings')
fig_tsne3.update_traces(marker=dict(size=3))
fig_tsne3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.1.1.min.js" integrity="sha256-HUEFyfiTnZJxCxur99FjbKYTvKSzwDaD3/x5TqHpFu4=" crossorigin="anonymous"></script>                <div id="933a5f09-3ea3-497f-b6ab-183f121ea133" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("933a5f09-3ea3-497f-b6ab-183f121ea133")) {                    Plotly.newPlot(                        "933a5f09-3ea3-497f-b6ab-183f121ea133",                        [{"hovertemplate":"type=common\u003cbr\u003ex=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"common","marker":{"color":"#636efa","symbol":"circle","size":3},"mode":"markers","name":"common","scene":"scene","showlegend":true,"x":{"dtype":"f4","bdata":"poIEwWXODsFvhSXB8ksVwY0Z7MA\u002fPQTAdNLXwe4FHcFZYpNByGDpwC6Nh8Ah2DrASp2VQIm8ZsHZb6zACI14wMBT1cHZ\u002fJfAoU3QwVyb+b\u002fC6HZAiwlowWdesMEGKbVBnCKDQYCuusEjV5LBDoDJQYC3uUEkpQfAj1SZPjKprcBg9INBf0TmQNS\u002fW0Dy5upAaP\u002flQKOGTcD88HDBUixDQX2fjMBIkd9BCMJlQDsC9z+0DCNCvDpxQSac9UHu\u002f+HAcj0LwcKuDMKFuTTAefAzQDGAjsAGKbRBJI\u002fKPnHfqT\u002fjFo1BJG2HQFq6HMKrDv1B8lS6wTv3wMEefy7CfLCMQSR0wkHXE2NAmSW7wVGtxsFceYtBrP4NQvqEf0FOyKHBQlxPwsLft0F2okvB9OHVwTDoHsJqRchB+Mk\u002fwk9bqsGErHDClwylQaN7HMJQK5JBbnW5QZ7lnMF+jydBYgb1PyjrfUF4GCRB+Ml1wh3wl78IVgHCPWplwvdmR0DoOjbCtA9YQYnxCkGgwarBuPQdwsBxD0Ga5A1CTHCjQQ\u002fxwsEuvtTB42o4wqDJ4cGNpOPA3K4WwpfjtUGA+DnBvFSIwRah+sHlazlBx\u002f9KwT1lqsH9iqZAzKdKQbgCQMFHQgNBxs1owA23A8KCav\u002fBCz6hwWiShcE3xY1BQ\u002fIbwh+I4MFC6BJBlCCTQeCI6UEnPLzBi+41wYgr5EA3tqxA+QTwwfrbFsKIqv3BsqLuwaV7TcJ0Lw3CHIZfwlofE8L03L9A25c6QWTONMKednzBEGMiwqeTKsK\u002fyRTB+2K2QEjGSkH8eVVBU7+8vm4NAcI1YelBHAD8wfBLeMLdW9RBtQefvm6nV8JOwVBBppAZQpUZZMHPMgRBxQlMwvEwpsGGWXPB93kQwkRiFkG9dCHBQdQ9whQOI8KbC2vBdHUMv+IOG0EDnrhABQxPwqmHGcLwSJNAEH2jQVruiUHs6O\u002fBopc7wuQoH8LWay3CCMhRwqxcxMH3G6lB2U8lQcpEOz94hCRBZmQOQgKuQcIxlBHCrJ1GwpxXwcCxOc5Bp\u002fTgQEdlK8I="},"y":{"dtype":"f4","bdata":"OiScQeYiJcFU8JjATAi0QfttxsCbEaLA7AIlQVsKekFcbKFBZRX8QRyL\u002f0CpRQBC\u002flGUwX9SOUGEaIjB0mIowtPXpsHExQ3AHa\u002flQJ0AtkAZIEPBXmTuQF9q4L8nHyVCYdItQpFNj0G2tI5B80WUQQ7bSEEDIoJBJSmmwVSa2MH0UAfCgvzywSTv18D55iTCBAxqwZva8cBJtvrBrya5wZMqDsLNGio\u002f0Z66wTbRT8HC7YNAzmIEQh7iNUFl9NxBynVkQNkYuUCzqgdCQ7MEwskB7sGTevfAAmFNwaI0f8Egt5zBh569QSuukUHl+abBnDAPQpWYxUCNoJTAT46owaLDNb7GwtZBtOPeQR6wqkBFIOi\u002fwmI1wUgfmr\u002fppDhBE2X7wIBNxcHC3vc+3NfWQYMDbsAwQl7B9D\u002fpwRZ9v7\u002fnTrTBZrfGQM2+VL3zfxDB+Xmcwc\u002fkEcKi5qrBJvqkwaz2DsDujBBClKpJwSbyEEAYwlTBMnmGwbZ7osGY+\u002fDBpmE2wcGDxEHQuo8\u002f0tf3wS9cXD8vp5vAGDgaQHvapUEHXs\u002fBbJ3eQN7p70BmybLBwvF1QIUpIcGvpqu\u002ffXCBwd53s8GJEx\u002fBNtpgwd\u002f1usHrEhTAsNddQc77KcFbArPAPcUOQM2bmsAEAJTAPs4NwqfgjEH\u002f8Z4\u002fR1qSQSrIS0HAKgLCdyfVQTOYXMFlGu9BBNYbwiIXtMEIkRfCi1caQl+lp8EZM9VBLgf\u002fQQf4E0FPZRjCLoW+wSNQ8sHIO5dAMfG8wLXF7UHwKOnB4nT2wKesyMFbOHrBLQIlPQlodsByMkPC\u002foGKQThkkcEV\u002fVvAup8gwcxNj8CyD4e\u002fl7WsP9hGU8Fz8wdBleyBQPwpssFaAkbC3gMTwrevi8Fm29G\u002fTRwhQc+Dz0CwTSlBtC5iwTuMG8FbefrANSbMwec8q0F5xjlCmosRwRxn3cEPJbtA8RNJQZNVH8GL5xLBIjl8wVd0csEoCOrABjGoQeZ2PsH9FU5B96NbwUslFL9UreVAw\u002fWuQCGHjUAyU\u002ffBlmfUQeq9IUL+K4C\u002ftiBTQRkjT0E="},"z":{"dtype":"f4","bdata":"F9zhQZkt1UEQPQdCQemgQY6gjkJmW9BB\u002fgeWQfyoSUJssCFCJo0vQguTr0G2JnBCprNAQtppjUEcPxhC66I3QjxCd0L2O31BkyRfQnCy+EE\u002fJyNCO\u002fjvQReUyEGSMxRC3VcZQqyzxkGKn3xCt2NkQsIxREIAtitCLfRqQsGrNELrsWdCC2lsQud0RkK\u002fMWVCkRFuQhpIJUL4tFpC2YdxQp0kYUKBOYZCG\u002fYZQonll0Kt7CpCuoREQnmD\u002fEHK4ApCdLMlQsVRBELEgMNB7S9MQm3gF0JTTIZCw+GFQq\u002fbgkHo5AFCkGyJQq9sykGKexpC5AEfQjgbLEJBzrJBWE84QpfADEIYGnRCsjAtQqdrf0KcO8xBpV7PQXbigUKPKYdC81F9Qa2QCEKEnWNBOQj5QTTh70H\u002fXwFCGpAIQsSyEkKXk4VA986JQqhsgEEbaGBC24dQQnqDj0H3fpdCCJG3QclWk0KSHy1Cjer0Qd\u002fGJ0I6ENBAA+gmQRPTiEJeyM9ADVDdQfz9XELkAydBG\u002fgWQbiFRkKNdBdC+KdRQntEYkKOOjNBt0nuQZbUDELiLYpCcgS2QQldyUGJxMZBjlEMQoFIB0FVx0hCxzAzQtJoGU ...

# %% [markdown]
# ##6.Similarity Search:

# %%
# use gensim's built-in similarity
query_word = random.choice(words)
top_k = 10
print("Query word:", query_word)
print(f"Top {top_k} most similar words (gensim):")
sim_list = model.most_similar(query_word, topn=top_k)
for w,score in sim_list:
    print(f"{w}\t{score:.4f}")
# Out:
# Query word: work
# Top 10 most similar words (gensim):
# working	0.8774
# works	0.8548
# well	0.8274
# worked	0.8128
# done	0.8112
# so	0.7680
# way	0.7633
# how	0.7614
# this	0.7587
# and	0.7481

# %%
if query_word in words:
    q_idx = words.index(query_word)
    q_pca2 = X_pca2[q_idx]
    q_tsne2 = X_tsne2[q_idx]
    # Cosine similarity helpers
    def cos_sim(a,b):
        denom = (np.linalg.norm(a) * np.linalg.norm(b))
        return (np.dot(a,b)/denom) if denom != 0 else 0.0

    # compute similarities in PCA 2D space
    sims_pca2 = [(words[i], cos_sim(q_pca2, X_pca2[i])) for i in range(len(words))]
    sims_pca2 = sorted(sims_pca2, key=lambda x: -x[1])[1:top_k+1]  # exclude self
    print("\nTop similar by PCA 2D (sampled vocab):")
    for w,s in sims_pca2:
        print(f"{w}\t{s:.4f}")

    # compute similarities in t-SNE 2D space
    sims_tsne2 = [(words[i], cos_sim(q_tsne2, X_tsne2[i])) for i in range(len(words))]
    sims_tsne2 = sorted(sims_tsne2, key=lambda x: -x[1])[1:top_k+1]
    print("\nTop similar by t-SNE 2D (sampled vocab):")
    for w,s in sims_tsne2:
        print(f"{w}\t{s:.4f}")
else:
    print("Query word not in sampled vocabulary; skip reduced-space similarity check.")
# Out:
# Top similar by PCA 2D (sampled vocab):
# many	1.0000
# still	1.0000
# just	1.0000
# be	1.0000
# have	0.9999
# could	0.9999
# any	0.9999
# used	0.9999
# all	0.9998
# "	0.9997
#
# Top similar by t-SNE 2D (sampled vocab):
# work	1.0000
# is	1.0000
# nursing	1.0000
# has	1.0000
# also	1.0000
# this	1.0000
# k-12	1.0000
# city	1.0000
# which	1.0000
# school	1.0000

# %% [markdown]
# ##7.Comments
#
# Dựa trên các kết quả đã chạy:
#
# 1.  **Giảm chiều dữ liệu bằng:**
#     *   **PCA:** Giúp nhìn thấy bức tranh tổng thể về mối quan hệ giữa các từ. Tuy nhiên, các từ có nghĩa gần nhau có thể vẫn nằm khá xa nhau trên biểu đồ 2D/3D.
#     *   **t-SNE:** Thường tạo ra các nhóm từ chặt chẽ hơn cho những từ có nghĩa gần nhau. t-SNE tốt hơn trong việc hiển thị cấu trúc cục bộ (các từ hàng xóm gần nhau).
#
# 2.  **Trực quan hóa 2D và 3D:**
#     *   Các biểu đồ giúp chúng ta "nhìn" được mối quan hệ giữa các từ trong không gian nhúng.
#     *   Biểu đồ 3D (sử dụng Plotly) cho phép xoay và tương tác, giúp khám phá cấu trúc dữ liệu tốt hơn khi các nhóm từ không thể tách rời hoàn toàn trong không gian 2D.
#     *   Việc chỉ hiển thị một số từ phổ biến/ngẫu nhiên giúp biểu đồ không bị quá tải và dễ nhìn hơn.
#
# 3.  **Tìm kiếm từ tương tự:**
#     *   Khi tìm kiếm các từ tương tự bằng mô hình gốc (gensim), kết quả thường rất chính xác về mặt ngữ nghĩa (ví dụ: tìm từ giống "work" ra "working", "works", "worked").
#     *   Khi tìm kiếm từ tương tự trong không gian đã giảm chiều (PCA 2D, t-SNE 2D), kết quả có thể không chính xác bằng mô hình gốc. Điều này cho thấy việc giảm chiều dữ liệu xuống 2D/3D đã làm mất đi một phần thông tin về mối quan hệ giữa các từ.
#     *   Kết quả tìm kiếm tương tự trong t-SNE 2D có vẻ "giống" với mô hình gốc hơn so với PCA 2D, điều này phù hợp với nhận xét rằng t-SNE bảo toàn cấu trúc cục bộ tốt hơn.
#
# **Tóm lại:**
#
# *   PCA và t-SNE là những công cụ hữu ích để hình dung dữ liệu nhúng từ (word embeddings).
# *   t-SNE thường tốt hơn cho việc xem các từ gần nhau về nghĩa tạo thành nhóm như thế nào.
# *   Giảm chiều dữ liệu giúp trực quan hóa nhưng cũng làm mất đi một phần thông tin.
# *   Để tìm kiếm từ tương tự chính xác nhất, nên sử dụng không gian nhúng gốc thay vì không gian đã giảm chiều.
